# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'a', 'originated', 'anarchism', 'originated', 'as', 'of', 'term']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  #tf.global_variables_initializer().run()
  session.run(tf.initialize_all_variables())
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.062588
# Nearest to time: gretchen, candid, emerged, tanenbaum, transitions, workplaces, irrevocably, macroeconomic,
# Nearest to history: sickness, closed, defeats, breaches, funneled, bootp, characterization, restated,
# Nearest to than: spandau, marina, kingdoms, ousting, tectonics, diff, pedagogy, scared,
# Nearest to three: weekend, navier, shortness, falun, retroviruses, metallic, beginner, destruction,
# Nearest to however: saracens, prompting, unauthorised, dragoon, analgesia, rinsing, outweigh, cabin,
# Nearest to that: shutout, title, functioning, notorious, dari, brutality, britten, screening,
# Nearest to if: infallibility, channels, behaves, dakota, hand, countermeasures, rooted, macabre,
# Nearest to often: crosstown, discriminated, fargo, alphorn, seperate, philanthropy, neurotransmitter, latent,
# Nearest to b: chs, sst, samarkand, grin, federalism, mitsuda, hallmark, dcs,
# Nearest to nine: preyed, materials, papyri, auditorium, equites, stalinist, praised, firebird,
# Nearest to about: sobriquet, photon, foreshadow, sterilization, exclusion, digs, springboard, buddhists,
# Nearest to state: astrometric, rapids, matriarch, naaman, beginners, mikvah, eulogy, jacopo,
# Nearest to when: sceptical, leonis, chains, sadr, spotting, interactions, ritchie, fenway,
# Nearest to use: everest, haiti, concede, helix, railways, anthologies, assigning, bugatti,
# Nearest to d: providers, justin, believable, navigable, pyramidal, timbre, decorate, grips,
# Nearest to may: dasyprocta, shareware, tandem, nfl, jagiellonian, broke, encircled, astounding,
# Average loss at step 2000: 4.353465
# Average loss at step 4000: 3.867575
# Average loss at step 6000: 3.786238
# Average loss at step 8000: 3.685609
# Average loss at step 10000: 3.617514
# Nearest to time: necronomicon, ideas, amigaos, hatchback, privations, pleiades, tanenbaum, transitions,
# Nearest to history: restated, mf, amor, examples, fao, churning, rejoining, revolution,
# Nearest to than: rematch, marina, painted, winnie, sadr, triggering, cooperates, carlist,
# Nearest to three: four, seven, five, six, eight, two, nine, zero,
# Nearest to however: larmor, telangana, renovate, saracens, chickie, maximise, dragoon, catalytic,
# Nearest to that: shutout, which, although, notorious, title, caledonians, toll, he,
# Nearest to if: unrivaled, hand, behaves, chandler, sultan, countermeasures, rummel, dakota,
# Nearest to often: sometimes, also, difficult, philanthropy, fargo, discriminated, crosstown, shanahan,
# Nearest to b: federalism, bahnhof, dcs, calvert, d, hallmark, gertrude, pendant,
# Nearest to nine: eight, six, seven, five, zero, four, three, two,
# Nearest to about: colloidal, maids, digs, sterilization, chakras, foosball, population, mercedes,
# Nearest to state: ecliptic, karakoram, cip, lovelock, daily, mikvah, analytic, ingest,
# Nearest to when: cruijff, chains, sceptical, leonis, leicester, joe, errico, clo,
# Nearest to use: concede, assigning, edith, hydrate, hipc, helix, haiti, depositing,
# Nearest to d: providers, justin, thinker, grips, blockade, b, laborious, pyramidal,
# Nearest to may: jagiellonian, could, would, can, nfl, yachts, tandem, sergio,
# Average loss at step 12000: 3.600212
# Average loss at step 14000: 3.573827
# Average loss at step 16000: 3.406881
# Average loss at step 18000: 3.458266
# Average loss at step 20000: 3.538514
# Nearest to time: necronomicon, period, way, year, hatchback, pleiades, osu, tanenbaum,
# Nearest to history: restated, revolution, examples, mf, neolithic, angles, favouring, fao,
# Nearest to than: or, marina, much, rematch, painted, conspirator, winnie, topography,
# Nearest to three: six, four, five, seven, two, eight, zero, nine,
# Nearest to however: but, larmor, nor, telangana, where, mayr, homecoming, although,
# Nearest to that: which, shutout, dtp, but, notorious, grrm, hbp, synagogue,
# Nearest to if: when, but, though, is, toyota, since, chandler, although,
# Nearest to often: also, sometimes, usually, fredrik, difficult, which, shanahan, generally,
# Nearest to b: d, reclaiming, meisner, wormhole, pikemen, bahnhof, greenwich, outlandish,
# Nearest to nine: eight, six, seven, four, five, three, zero, two,
# Nearest to about: maids, colloidal, polanski, digs, buddhists, september, mercedes, population,
# Nearest to state: ingest, daily, lovelock, jacopo, lower, analytic, ecliptic, cip,
# Nearest to when: if, chains, while, was, fielders, kyrgyz, requires, strives,
# Nearest to use: concede, assigning, exist, depositing, hydrate, edith, athenian, truths,
# Nearest to d: b, justin, providers, grips, thinker, french, severity, loomis,
# Nearest to may: can, would, could, will, must, might, should, jagiellonian,
# Average loss at step 22000: 3.499396
# Average loss at step 24000: 3.491226
# Average loss at step 26000: 3.480572
# Average loss at step 28000: 3.478369
# Average loss at step 30000: 3.499922
# Nearest to time: period, year, necronomicon, way, pleiades, dtp, osu, principled,
# Nearest to history: restated, revolution, institute, fao, rainer, neolithic, scribes, angles,
# Nearest to than: rematch, much, winnie, topography, painted, conspirator, kgb, triggering,
# Nearest to three: four, five, eight, six, seven, two, nine, zero,
# Nearest to however: but, although, where, nor, while, that, substratum, homecoming,
# Nearest to that: which, but, this, what, shutout, although, notorious, who,
# Nearest to if: when, although, though, since, lashes, is, where, toyota,
# Nearest to often: sometimes, usually, also, generally, there, fredrik, commonly, typically,
# Nearest to b: d, reclaiming, kk, greenwich, f, hams, meisner, envoy,
# Nearest to nine: eight, seven, six, five, four, three, zero, one,
# Nearest to about: maids, colloidal, polanski, population, moose, stitches, situs, on,
# Nearest to state: daily, diatonic, lovelock, government, milford, ingest, vitruvius, guez,
# Nearest to when: if, while, after, before, though, was, during, where,
# Nearest to use: concede, assigning, exist, athenian, sed, object, depositing, yu,
# Nearest to d: b, justin, pap, thinker, births, severity, providers, loomis,
# Nearest to may: can, would, could, will, must, should, might, cannot,
# Average loss at step 32000: 3.503320
# Average loss at step 34000: 3.493638
# Average loss at step 36000: 3.452440
# Average loss at step 38000: 3.297433
# Average loss at step 40000: 3.425817
# Nearest to time: period, way, necronomicon, year, pleiades, labs, years, vocative,
# Nearest to history: revolution, scribes, amor, suny, institute, characterization, restated, fao,
# Nearest to than: or, much, rematch, winnie, painted, topography, conspirator, pattie,
# Nearest to three: four, five, six, two, seven, eight, one, nine,
# Nearest to however: but, although, that, while, substratum, where, fighting, calamities,
# Nearest to that: which, what, however, this, but, caledonians, who, cherokee,
# Nearest to if: when, using, where, although, is, though, in, since,
# Nearest to often: sometimes, usually, also, generally, commonly, typically, never, frequently,
# Nearest to b: d, f, UNK, r, births, c, gls, affections,
# Nearest to nine: eight, seven, six, five, four, zero, three, one,
# Nearest to about: polanski, aznar, situs, stitches, chopping, ribosomes, freeport, maids,
# Nearest to state: government, daily, eschew, weekly, diatonic, bedfordshire, ingest, vitruvius,
# Nearest to when: if, while, before, after, though, where, obe, cadres,
# Nearest to use: solidly, concede, athenian, assigning, exist, be, eighties, quality,
# Nearest to d: b, aggressors, severity, c, spartan, envoy, e, standardised,
# Nearest to may: can, would, will, could, must, might, should, cannot,
# Average loss at step 42000: 3.433383
# Average loss at step 44000: 3.454179
# Average loss at step 46000: 3.448537
# Average loss at step 48000: 3.352359
# Average loss at step 50000: 3.379141
# Nearest to time: period, way, pleiades, lasting, year, day, escalate, necronomicon,
# Nearest to history: revolution, scribes, breaches, list, shlomo, gmail, amor, untouchable,
# Nearest to than: or, much, averaging, jehoshaphat, cooperates, koto, prominent, brazilians,
# Nearest to three: six, four, seven, eight, five, two, nine, zero,
# Nearest to however: but, although, while, that, where, homecoming, substratum, when,
# Nearest to that: which, however, what, doing, commemorated, brassiere, but, who,
# Nearest to if: when, although, where, though, using, since, requires, while,
# Nearest to often: usually, sometimes, generally, commonly, frequently, typically, also, widely,
# Nearest to b: d, f, p, k, scott, los, births, gls,
# Nearest to nine: eight, six, seven, four, five, three, zero, one,
# Nearest to about: moose, stitches, around, polanski, freeport, lai, aznar, ribosomes,
# Nearest to state: government, bedfordshire, weekly, daily, diatonic, frankfort, sept, restoration,
# Nearest to when: if, before, while, after, where, but, though, although,
# Nearest to use: assigning, quality, poset, athenian, solidly, list, eighties, order,
# Nearest to d: b, c, f, e, envoy, m, aggressors, k,
# Nearest to may: can, would, could, will, should, must, might, cannot,
# Average loss at step 52000: 3.437328
# Average loss at step 54000: 3.426878
# Average loss at step 56000: 3.442561
# Average loss at step 58000: 3.395468
# Average loss at step 60000: 3.395901
# Nearest to time: way, period, pleiades, passing, day, escalate, transitions, bamako,
# Nearest to history: scribes, list, politics, dictionary, gmail, shlomo, revolution, hinds,
# Nearest to than: or, much, but, averaging, and, koto, syme, rematch,
# Nearest to three: five, four, eight, seven, six, two, nine, one,
# Nearest to however: but, although, which, that, while, since, calamities, when,
# Nearest to that: which, this, however, what, shutout, it, doing, meme,
# Nearest to if: when, though, where, although, before, since, did, because,
# Nearest to often: usually, sometimes, commonly, generally, frequently, typically, also, widely,
# Nearest to b: d, f, p, k, l, m, c, onwards,
# Nearest to nine: eight, six, four, seven, five, three, zero, one,
# Nearest to about: polanski, around, moose, ballets, freeport, lai, on, ingalls,
# Nearest to state: government, weekly, restoration, daily, bedfordshire, frankfort, diatonic, leaders,
# Nearest to when: if, while, before, after, where, although, during, because,
# Nearest to use: solidly, athenian, sense, poset, object, assigning, quality, concede,
# Nearest to d: b, f, c, e, aggressors, m, y, envoy,
# Nearest to may: can, would, will, could, must, should, might, cannot,
# Average loss at step 62000: 3.240877
# Average loss at step 64000: 3.254879
# Average loss at step 66000: 3.404815
# Average loss at step 68000: 3.391883
# Average loss at step 70000: 3.355082
# Nearest to time: period, way, escalate, athabasca, immaculate, disembarked, lasting, place,
# Nearest to history: list, version, scribes, hinds, dictionary, revolution, gmail, politics,
# Nearest to than: or, much, but, and, averaging, kgb, topography, northridge,
# Nearest to three: four, six, two, five, seven, eight, nine, one,
# Nearest to however: but, although, while, though, that, where, since, which,
# Nearest to that: which, what, however, this, but, shutout, hbp, often,
# Nearest to if: when, though, where, although, before, since, because, while,
# Nearest to often: sometimes, usually, commonly, generally, now, frequently, typically, also,
# Nearest to b: d, f, l, n, p, brisingamen, k, broadsword,
# Nearest to nine: eight, six, seven, five, four, zero, three, one,
# Nearest to about: on, over, regarding, around, freeport, ingalls, polanski, lai,
# Nearest to state: weekly, government, states, guez, strained, ligamentum, irons, fox,
# Nearest to when: if, while, before, because, though, after, was, where,
# Nearest to use: solidly, cause, sense, support, allow, poset, form, concept,
# Nearest to d: b, f, aggressors, envoy, ca, y, e, pap,
# Nearest to may: can, would, will, could, should, might, must, cannot,
# Average loss at step 72000: 3.369874
# Average loss at step 74000: 3.348013
# Average loss at step 76000: 3.312624
# Average loss at step 78000: 3.350115
# Average loss at step 80000: 3.378862
# Nearest to time: period, athabasca, yana, bamako, pleiades, escalate, way, discovering,
# Nearest to history: list, scribes, version, hinds, dictionary, dvi, gmail, melaka,
# Nearest to than: or, much, but, averaging, koto, and, jethro, topography,
# Nearest to three: four, six, five, two, seven, eight, nine, one,
# Nearest to however: although, but, though, while, that, where, especially, caldera,
# Nearest to that: which, however, telnet, shutout, grrm, this, hbp, what,
# Nearest to if: when, though, before, since, although, because, after, where,
# Nearest to often: sometimes, usually, commonly, generally, now, frequently, typically, also,
# Nearest to b: d, f, sussman, c, p, severity, narrowing, k,
# Nearest to nine: eight, seven, six, five, four, three, zero, one,
# Nearest to about: ingalls, around, moose, over, freeport, shikoku, polanski, ballets,
# Nearest to state: government, weekly, states, sofie, city, union, fox, territory,
# Nearest to when: before, if, though, while, after, although, during, where,
# Nearest to use: list, support, sense, form, way, reggaeton, poset, tracking,
# Nearest to d: b, f, aggressors, severity, y, verses, barbaric, minos,
# Nearest to may: can, could, would, will, might, should, must, cannot,
# Average loss at step 82000: 3.408066
# Average loss at step 84000: 3.409874
# Average loss at step 86000: 3.383962
# Average loss at step 88000: 3.349380
# Average loss at step 90000: 3.357859
# Nearest to time: period, athabasca, yana, escalate, bamako, masamune, pleiades, year,
# Nearest to history: list, scribes, dictionary, version, see, pessoa, shalom, gmail,
# Nearest to than: much, or, brazilians, negated, jethro, hillsides, averaging, details,
# Nearest to three: two, four, five, seven, eight, six, one, nine,
# Nearest to however: but, although, that, though, while, since, especially, where,
# Nearest to that: which, however, shutout, grrm, hbp, doing, what, notorious,
# Nearest to if: when, where, since, although, before, though, after, did,
# Nearest to often: sometimes, usually, commonly, generally, frequently, now, also, still,
# Nearest to b: d, f, narrowing, sussman, l, onwards, k, c,
# Nearest to nine: seven, eight, six, five, four, zero, three, two,
# Nearest to about: over, around, regarding, ingalls, freeport, polanski, lai, cowper,
# Nearest to state: government, weekly, city, reel, naaman, frankfort, sofie, brainwashed,
# Nearest to when: if, before, while, after, although, though, where, during,
# Nearest to use: list, poset, way, support, pashtuns, sense, solidly, transmission,
# Nearest to d: b, f, aggressors, kalmyks, y, envoy, kearney, bodied,
# Nearest to may: can, could, would, might, should, will, must, cannot,
# Average loss at step 92000: 3.398150
# Average loss at step 94000: 3.251852
# Average loss at step 96000: 3.355510
# Average loss at step 98000: 3.239721
# Average loss at step 100000: 3.357007
# Nearest to time: period, pleiades, year, escalate, athabasca, discovering, vocative, month,
# Nearest to history: list, dictionary, scribes, version, success, pessoa, mathematical, islamic,
# Nearest to than: or, much, brazilians, outraged, jethro, details, while, dessert,
# Nearest to three: four, two, six, five, eight, seven, one, nine,
# Nearest to however: but, although, that, especially, while, though, where, nor,
# Nearest to that: which, however, what, but, shutout, who, hbp, telnet,
# Nearest to if: when, though, before, where, although, requires, since, did,
# Nearest to often: sometimes, usually, commonly, generally, frequently, still, now, typically,
# Nearest to b: d, sussman, justin, bijective, brisingamen, leon, crowns, onwards,
# Nearest to nine: eight, seven, six, four, five, zero, three, one,
# Nearest to about: around, ingalls, over, regarding, polanski, ballets, aces, freeport,
# Nearest to state: government, weekly, frankfort, city, fox, naaman, guez, daily,
# Nearest to when: if, while, before, although, after, though, where, because,
# Nearest to use: support, sense, cause, solidly, woodwinds, asanga, way, list,
# Nearest to d: b, c, justin, severity, hurst, f, aggressors, pap,
# Nearest to may: can, could, might, should, would, will, must, cannot,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
final_embeddings.shape
type(final_embeddings)
# Out:
# numpy.ndarray

# %%
np.save('embedding.npy', final_embeddings)
import pickle
pickle.dump(reverse_dictionary, open('rev_dict.p', 'wb'))

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
